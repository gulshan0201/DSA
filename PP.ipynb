# %% [markdown]
# <a href="https://colab.research.google.com/github/gulshan0201/DSA/blob/main/PP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 0
while i < 5:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
arr = [9,23,45,22]

print(arr[0])

arr.append(100)
print(arr)
# Out:
# 9
# [9, 23, 45, 22, 100]

# %%
def is_even(number):
    return number % 2 == 0

# Example usage:
num = 10
if is_even(num):
    print(f"{num} is even")
else:
    print(f"{num} is odd")

num = 7
if is_even(num):
    print(f"{num} is even")
else:
    print(f"{num} is odd")
# Out:
# 10 is even
# 7 is odd
