# %% [markdown]
# <a href="https://colab.research.google.com/github/gulshan0201/DSA/blob/main/Binary_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Binary Search Tree (BST) with Insert, Multiple Insert, Search, Delete - Menu Driven

class Node:
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None


class BinarySearchTree:
    def __init__(self):
        self.root = None

    # Insert operation
    def insert(self, key):
        self.root = self._insert_recursive(self.root, key)

    def _insert_recursive(self, root, key):
        if root is None:
            return Node(key)
        if key < root.key:
            root.left = self._insert_recursive(root.left, key)
        elif key > root.key:
            root.right = self._insert_recursive(root.right, key)
        # If key == root.key, we ignore duplicates (optional)
        return root

    # Search operation
    def search(self, key):
        return self._search_recursive(self.root, key)

    def _search_recursive(self, root, key):
        if root is None:
            return False
        if key == root.key:
            return True
        elif key < root.key:
            return self._search_recursive(root.left, key)
        else:
            return self._search_recursive(root.right, key)

    # Delete operation
    def delete(self, key):
        self.root = self._delete_recursive(self.root, key)

    def _delete_recursive(self, root, key):
        if root is None:
            return root

        if key < root.key:
            root.left = self._delete_recursive(root.left, key)
        elif key > root.key:
            root.right = self._delete_recursive(root.right, key)
        else:
            # Node found
            # Case 1: No child
            if root.left is None and root.right is None:
                return None

            # Case 2: One child
            if root.left is None:
                return root.right
            if root.right is None:
                return root.left

            # Case 3: Two children
            successor = self._min_value_node(root.right)
            root.key = successor.key
            root.right = self._delete_recursive(root.right, successor.key)

        return root

    def _min_value_node(self, node):
        current = node
        while current.left:
            current = current.left
        return current

    # Traversals
    def inorder(self):
        if self.root is None:
            print("Tree is empty.")
        else:
            print("Inorder traversal:", end=" ")
            self._inorder_recursive(self.root)
            print()

    def _inorder_recursive(self, root):
        if root:
            self._inorder_recursive(root.left)
            print(root.key, end=" ")
            self._inorder_recursive(root.right)

    def preorder(self):
        if self.root is None:
            print("Tree is empty.")
        else:
            print("Preorder traversal:", end=" ")
            self._preorder_recursive(self.root)
            print()

    def _preorder_recursive(self, root):
        if root:
            print(root.key, end=" ")
            self._preorder_recursive(root.left)
            self._preorder_recursive(root.right)

    def postorder(self):
        if self.root is None:
            print("Tree is empty.")
        else:
            print("Postorder traversal:", end=" ")
            self._postorder_recursive(self.root)
            print()

    def _postorder_recursive(self, root):
        if root:
            self._postorder_recursive(root.left)
            self._postorder_recursive(root.right)
            print(root.key, end=" ")


# ============================
#       MAIN PROGRAM
# ============================

def main():
    bst = BinarySearchTree()

    while True:
        print("\n==== Binary Search Tree Menu ====")
        print("1. Insert (single/multiple values)")
        print("2. Search")
        print("3. Delete")
        print("4. Inorder Traversal")
        print("5. Preorder Traversal")
        print("6. Postorder Traversal")
        print("7. Exit")

        choice = input("Enter your choice (1-7): ").strip()

        if choice == "1":
            # Multiple insert support
            nums_str = input("Enter value(s) to insert (separated by spaces or commas): ")
            # Replace commas with spaces and split
            parts = nums_str.replace(",", " ").split()

            for p in parts:
                try:
                    val = int(p)
                    bst.insert(val)
                    print(f"Inserted: {val}")
                except ValueError:
                    print(f"Skipped invalid input: {p}")

        elif choice == "2":
            try:
                val = int(input("Enter value to search: "))
                if bst.search(val):
                    print(val, "found in the tree.")
                else:
                    print(val, "not found in the tree.")
            except ValueError:
                print("Invalid input. Please enter an integer.")

        elif choice == "3":
            try:
                val = int(input("Enter value to delete: "))
                bst.delete(val)
                print("Delete operation completed for:", val)
            except ValueError:
                print("Invalid input. Please enter an integer.")

        elif choice == "4":
            bst.inorder()

        elif choice == "5":
            bst.preorder()

        elif choice == "6":
            bst.postorder()

        elif choice == "7":
            print("Exiting program...")
            break

        else:
            print("Invalid choice! Enter a number between 1 and 7.")


if __name__ == "__main__":
    main()

# %% [markdown]
# Binary search trees

# %%
# Node class
class Node:
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None


# Binary Tree class
class BinaryTree:
    def __init__(self):
        self.root = None

    # Insert nodes (Level Order Insertion)
    def insert(self, key):
        new_node = Node(key)
        if not self.root:
            self.root = new_node
            return

        queue = [self.root]
        while queue:
            current = queue.pop(0)

            if current.left is None:
                current.left = new_node
                return
            else:
                queue.append(current.left)

            if current.right is None:
                current.right = new_node
                return
            else:
                queue.append(current.right)

    # Inorder Traversal (Left -> Root -> Right)
    def inorder(self, node):
        if node:
            self.inorder(node.left)
            print(node.key, end=" ")
            self.inorder(node.right)

    # Preorder Traversal (Root -> Left -> Right)
    def preorder(self, node):
        if node:
            print(node.key, end=" ")
            self.preorder(node.left)
            self.preorder(node.right)

    # Postorder Traversal (Left -> Right -> Root)
    def postorder(self, node):
        if node:
            self.postorder(node.left)
            self.postorder(node.right)
            print(node.key, end=" ")

    # Level Order Traversal
    def level_order(self):
        if not self.root:
            return
        queue = [self.root]
        while queue:
            current = queue.pop(0)
            print(current.key, end=" ")
            if current.left:
                queue.append(current.left)
            if current.right:
                queue.append(current.right)

    # Search operation (Level Order Search)
    def search(self, key):
        if not self.root:
            return False
        queue = [self.root]
        while queue:
            current = queue.pop(0)
            if current.key == key:
                return True
            if current.left:
                queue.append(current.left)
            if current.right:
                queue.append(current.right)
        return False

    # Helper to find the deepest and rightmost node
    def get_deepest_node(self):
        if not self.root:
            return None
        queue = [self.root]
        while queue:
            current = queue.pop(0)
            if current.left:
                queue.append(current.left)
            if current.right:
                queue.append(current.right)
        return current  # last node processed is deepest

    # Delete deepest node
    def delete_deepest(self, deepest_node):
        queue = [self.root]
        while queue:
            current = queue.pop(0)
            if current is deepest_node:
                current = None
                return
            if current.right:
                if current.right is deepest_node:
                    current.right = None
                    return
                else:
                    queue.append(current.right)
            if current.left:
                if current.left is deepest_node:
                    current.left = None
                    return
                else:
                    queue.append(current.left)

    # Delete a node with given key
    def delete(self, key):
        if not self.root:
            print("Tree is empty.")
            return

        queue = [self.root]
        key_node = None
        while queue:
            current = queue.pop(0)
            if current.key == key:
                key_node = current
            if current.left:
                queue.append(current.left)
            if current.right:
                queue.append(current.right)

        if not key_node:
            print(f"Node with key {key} not found.")
            return

        # Find deepest node
        deepest = self.get_deepest_node()
        # Replace target key with deepest node key
        key_node.key = deepest.key
        # Delete the deepest node
        self.delete_deepest(deepest)
        print(f"Node with key {key} deleted successfully.")


# Main program
if __name__ == "__main__":
    tree = BinaryTree()

    n = int(input("Enter number of nodes: "))
    print("Enter node values:")
    for _ in range(n):
        val = int(input())
        tree.insert(val)

    print("\nInorder Traversal: ", end="")
    tree.inorder(tree.root)

    print("\nPreorder Traversal: ", end="")
    tree.preorder(tree.root)

    print("\nPostorder Traversal: ", end="")
    tree.postorder(tree.root)

    print("\nLevel Order Traversal: ", end="")
    tree.level_order()

    # Search operation
    key = int(input("\n\nEnter key to search: "))
    if tree.search(key):
        print(f"Node {key} found in the tree.")
    else:
        print(f"Node {key} not found in the tree.")

    # Delete operation
    del_key = int(input("\nEnter key to delete: "))
    tree.delete(del_key)

    print("\nLevel Order Traversal after deletion: ", end="")
    tree.level_order()
    print()
# Out:
# Enter number of nodes: 5
# Enter node values:
# 11
# 43
# 21
# 71
# 14
#
# Inorder Traversal: 71 43 14 11 21
# Preorder Traversal: 11 43 71 14 21
# Postorder Traversal: 71 14 43 21 11
# Level Order Traversal: 11 43 21 71 14
#
# Enter key to search: 43
# Node 43 found in the tree.
#
# Enter key to delete: 14
# Node with key 14 deleted successfully.
#
# Level Order Traversal after deletion: 11 43 21 71

# %%
SIZE = 7
